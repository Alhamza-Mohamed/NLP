# %%
import numpy as np # Library for linear algebra and math utils
import pandas as pd # Dataframe library

import matplotlib.pyplot as plt # Library for plots
from utils import confidence_ellipse # Function to add confidence ellipses to charts
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 5
#       2 import pandas as pd # Dataframe library
#       4 import matplotlib.pyplot as plt # Library for plots
# ----> 5 from utils import confidence_ellipse # Function to add confidence ellipses to charts
#
# ImportError: cannot import name 'confidence_ellipse' from 'utils' (e:\courses\after graduation\Repos\NLP\Natural Language Processing with Classification and Vector Spaces course\utils.py)
